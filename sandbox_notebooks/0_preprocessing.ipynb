# %%
import snowflake.connector
import pandas as pd
import numpy as np

# %%
account = 'XXXXXXXXXXXXXXXX'
user = 'XXXXXXXXXXXXXXXX'
password = 'XXXXXXXXXXXXXXXX'
database = 'XXXXXXXXXXXXXXXX'
schema = 'XXXXXXXXXXXXXXXX'
warehouse = 'XXXXXXXXXXXXXXXX'

# %%
ctx = snowflake.connector.connect(
    user=user,
    password=password,
    account=account,
    database=database,
    schema=schema,
    warehouse=warehouse
)

# %%
account_query = "select * from salesforce_db.raw_data.account"
contact_query = "select * from salesforce_db.raw_data.contact"
opportunity_query = "select * from salesforce_db.raw_data.opportunity"
opportunitystage_query = "select * from salesforce_db.raw_data.opportunitystage"
task_query = "select * from salesforce_db.raw_data.task"

# %%
def get_table(ctx, query):
    cs = ctx.cursor()
    try:
        cs.execute(query)
        df = cs.fetch_pandas_all()
    finally:
        cs.close()
    return df

# %%
account = get_table(ctx, account_query)

# %%
opportunity = get_table(ctx, opportunity_query)

# %%
contact = get_table(ctx, contact_query)

# %%
opportunitystage = get_table(ctx, opportunitystage_query)

# %%
task = get_table(ctx, task_query)

# %%
ctx.close()

# %%
account.to_csv("raw_data/account.csv", index=False)
opportunity.to_csv("raw_data/opportunity.csv", index=False)
opportunitystage.to_csv("raw_data/opportunitystage.csv", index=False)
task.to_csv("raw_data/task.csv", index=False)
contact.to_csv("raw_data/contact.csv", index=False)

# %% [markdown]
# ## Functions

# %%
def print_missing_data_percentage(df, threshold=50):
    # Calculate the percentage of missing data for each column
    missing_data_percentage = df.isnull().mean() * 100

    # Filter columns with missing data greater than or equal to the threshold
    filtered_columns = missing_data_percentage[missing_data_percentage <= threshold]

    # Print the percentage of missing data for each filtered column
    print(f"Columns with Missing Data Less Than or Equal to {threshold}%:")
    columns = []
    for column, percentage in filtered_columns.sort_values(ascending=False).items():
        print(f"{column}: {percentage:.2f}%")
        columns.append(column)
    return columns

# %% [markdown]
# ## Account

# %%
account.head()
# Out:
#                    ID ISDELETED MASTERRECORDID  \
# 0  001ak00000IADL0AAP     False           None
# 1  001ak00000IADT3AAP     False           None
# 2  001ak00000IADT4AAP     False           None
# 3  001ak00000IADT7AAP     False           None
# 4  001ak00000IADT8AAP     False           None
#
#                                   NAME               TYPE PARENTID  \
# 0  Cuenta de ejemplo para asignaciones               None     None
# 1                  Edge Communications  Customer - Direct     None
# 2  Burlington Textiles Corp of America  Customer - Direct     None
# 3           Grand Hotels & Resorts Ltd  Customer - Direct     None
# 4               United Oil & Gas Corp.  Customer - Direct     None
#
#                                        BILLINGSTREET BILLINGCITY BILLINGSTATE  \
# 0                                               None        None         None
# 1      312 Constitution Place\nAustin, TX 78767\nUSA      Austin           TX
# 2                               525 S. Lexington Ave  Burlington           NC
# 3  2334 N. Michigan Avenue, Suite 1500\nChicago, ...     Chicago           IL
# 4  1301 Avenue of the Americas \r\nNew York, NY 1...    New York           NY
#
#   BILLINGPOSTALCODE  ...    SLA__C ACTIVE__C NUMBEROFLOCATIONS__C  \
# 0              None  ...      None      None                 None
# 1              None  ...    Silver       Yes                  2.0
# 2             27215  ...    Silver      None                  6.0
# 3              None  ...      Gold       Yes                 57.0
# 4              None  ...  Platinum       Yes                955.0
#
#   UPSELLOPPORTUNITY__C SLASERIALNUMBER__C         SLAEXPIRATIONDATE__C  \
# 0                 None               None                         None
# 1                Maybe               2657  2024-06-12 00:00:00.0000000
# 2                Maybe               5367  2024-06-12 00:00:00.0000000
# 3                  Yes               5572  2024-12-13 00:00:00.0000000
# 4                  Yes               6654  2024-12-13 00:00:00.0000000
#
#   OWNER_INTENT_TO_SELL__C TOTAL_FUNDING_TO_DATE__C GROWTH_RATE__C  \
# 0                   False                     None           None
# 1                   False                     None           None
# 2                   False                     None           None
# 3                   False                     None           None
# 4                   False                     None           None
#
#   HQ_LOCATION__C
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
#
# [5 rows x 68 columns]

# %%
# Handling Missing Values
print("Missing Values:")
account_columns = print_missing_data_percentage(account, threshold=20)
# Out:
# Missing Values:
# Columns with Missing Data Less Than or Equal to 20%:
# HQ_LOCATION__C: 1.96%
# GROWTH_RATE__C: 1.96%
# TOTAL_FUNDING_TO_DATE__C: 1.96%
# YEARSTARTED: 1.96%
# ACCOUNTSOURCE: 1.96%
# BILLINGLATITUDE: 1.96%
# BILLINGLONGITUDE: 1.96%
# SITE: 1.96%
# BILLINGPOSTALCODE: 1.76%
# BILLINGCOUNTRY: 1.76%
# ANNUALREVENUE: 0.78%
# DESCRIPTION: 0.78%
# RATING: 0.59%
# TICKERSYMBOL: 0.59%
# BILLINGCITY: 0.39%
# NUMBEROFEMPLOYEES: 0.20%
# OWNERSHIP: 0.20%
# INDUSTRY: 0.20%
# WEBSITE: 0.20%
# FAX: 0.20%
# PHONE: 0.20%
# TYPE: 0.20%
# BILLINGSTREET: 0.20%
# BILLINGSTATE: 0.20%
# SYSTEMMODSTAMP: 0.00%
# NAME: 0.00%
# OWNER_INTENT_TO_SELL__C: 0.00%
# CLEANSTATUS: 0.00%
# LASTMODIFIEDDATE: 0.00%
# LASTMODIFIEDBYID: 0.00%
# ISDELETED: 0.00%
# CREATEDBYID: 0.00%
# CREATEDDATE: 0.00%
# OWNERID: 0.00%
# PHOTOURL: 0.00%
# ID: 0.00%

# %%
f"# columns: {len(account_columns)}"
# Out:
# '# columns: 36'

# %%
account_0 = account[account_columns].copy()
# dropped rows with missing values in the custom fields HQ_LOCATION__C, GROWTH_RATE__C, TOTAL_FUNDING_TO_DATE__C, OWNER_INTENT_TO_SELL__C
account_0.dropna(subset=['HQ_LOCATION__C', 'GROWTH_RATE__C', 'TOTAL_FUNDING_TO_DATE__C', 'OWNER_INTENT_TO_SELL__C'], inplace=True)
# dropped unnecessary columns for now
columns_to_drop = ['BILLINGLATITUDE', 'BILLINGLONGITUDE', 'BILLINGPOSTALCODE', 'BILLINGCOUNTRY', 'DESCRIPTION', 'TICKERSYMBOL',
                   'BILLINGCITY', 'SITE', 'WEBSITE', 'FAX', 'PHONE', 'BILLINGSTREET', 'SYSTEMMODSTAMP', 'CLEANSTATUS', 'BILLINGSTATE',
                   'LASTMODIFIEDDATE', 'LASTMODIFIEDBYID', 'ISDELETED', 'CREATEDBYID', 'CREATEDDATE', 'OWNERID', 'PHOTOURL']
account_0.drop(columns=columns_to_drop, axis=0, inplace=True)

# %%
# Check for duplicates
print(f"Duplicates: {account_0.duplicated().sum()}")
# Out:
# Duplicates: 0

# %%
account_0.head()
# Out:
#    HQ_LOCATION__C GROWTH_RATE__C TOTAL_FUNDING_TO_DATE__C YEARSTARTED  \
# 10        Florida           28.0               12618042.5        2024
# 11   South Dakota          240.0              36166195.73        2018
# 12         Alaska          181.0              18847734.44        2016
# 13        Indiana           82.0                5496170.0        2022
# 14  New Hampshire           32.0              28215066.73        2015
#
#                      ACCOUNTSOURCE ANNUALREVENUE RATING NUMBEROFEMPLOYEES  \
# 10  Incubator/Accelerator Programs     9210250.0    Hot                47
# 11  Incubator/Accelerator Programs      27607783   Cold               139
# 12                Direct Referrals      22985042   Cold               115
# 13               Networking Events     5496170.0   Warm                28
# 14                Business Brokers      47822147   Warm               240
#
#      OWNERSHIP    INDUSTRY          TYPE  \
# 10     Private       Media       Startup
# 11      Public  Technology  Growth Stage
# 12      Public  Recreation  Growth Stage
# 13  Subsidiary  Healthcare       Startup
# 14     Private     Finance  Growth Stage
#
#                                        NAME OWNER_INTENT_TO_SELL__C  \
# 10                 Flores-Smith Enterprises                    True
# 11        Case, Holden and Shepard Holdings                   False
# 12  Griffin, Rivers and Higgins Enterprises                   False
# 13                     Meza Inc Corporation                   False
# 14                      Hansen Inc Holdings                    True
#
#                     ID
# 10  001ak00000IqvqPAAR
# 11  001ak00000IqvqQAAR
# 12  001ak00000IqvqRAAR
# 13  001ak00000IqvqSAAR
# 14  001ak00000IqvqTAAR

# %% [markdown]
# ## Opportunity

# %%
opportunity.head()
# Out:
#                    ID ISDELETED           ACCOUNTID ISPRIVATE         NAME  \
# 0  006ak000002sAjJAAU     False  001ak00000IrTIfAAN     False   Investment
# 1  006ak000002sAjKAAU     False  001ak00000IrtTVAAZ     False  Acquisition
# 2  006ak000002sAjLAAU     False  001ak00000IrtTWAAZ     False  Acquisition
# 3  006ak000002sAjMAAU     False  001ak00000IrtTXAAZ     False  Acquisition
# 4  006ak000002sAjNAAU     False  001ak00000IrtTYAAZ     False   Investment
#
#                                          DESCRIPTION    STAGENAME  \
# 0  Idea south create forget. Rate cost street bet...   Closed Won
# 1  Task expert full why organization hair wide. C...   Closed Won
# 2  Deal talk sea system single agree recently. Fe...  Closed Lost
# 3  Thought indeed positive fear much almost. Offi...  Closed Lost
# 4       Though book American. Billion cup win seven.  Closed Lost
#
#          AMOUNT PROBABILITY EXPECTEDREVENUE  ... FISCAL LASTVIEWEDDATE  \
# 0    9803283.28       100.0      9803283.28  ...      4           2017
# 1  769708262.96       100.0    769708262.96  ...      2           2011
# 2   15345608.43         0.0             0.0  ...      2           2023
# 3    14571650.3         0.0             0.0  ...      2           2024
# 4   53095439.02         0.0             0.0  ...      1           2012
#
#   LASTREFERENCEDDATE     HASOPENACTIVITY HASOVERDUETASK  \
# 0             2017 4  003ak000002nqKoAAI           None
# 1             2011 2  003ak000002nqKpAAI           None
# 2             2023 2  003ak000002nqKqAAI           None
# 3             2024 2  003ak000002nqKrAAI           None
# 4             2012 1  003ak000002nqKsAAI           None
#
#   DELIVERYINSTALLATIONSTATUS__C TRACKINGNUMBER__C ORDERNUMBER__C  \
# 0                          None              True           True
# 1                          None              True           True
# 2                          None              True           True
# 3                          None              True           True
# 4                          None              True           True
#
#   CURRENTGENERATORS__C MAINCOMPETITORS__C
# 0                 None               None
# 1                 None               None
# 2                 None               None
# 3                 None               None
# 4                 None               None
#
# [5 rows x 41 columns]

# %%
opportunity.drop_duplicates(subset=['ID', 'ACCOUNTID'], keep='first', inplace=True)

# %%
# Handling Missing Values
print("Missing Values:")
opportunity_columns = print_missing_data_percentage(opportunity, threshold=20)
# Out:
# Missing Values:
# Columns with Missing Data Less Than or Equal to 20%:
# ID: 0.00%
# ISDELETED: 0.00%
# TRACKINGNUMBER__C: 0.00%
# HASOPENACTIVITY: 0.00%
# LASTREFERENCEDDATE: 0.00%
# LASTVIEWEDDATE: 0.00%
# FISCAL: 0.00%
# FISCALQUARTER: 0.00%
# SYSTEMMODSTAMP: 0.00%
# LASTMODIFIEDBYID: 0.00%
# LASTMODIFIEDDATE: 0.00%
# CREATEDBYID: 0.00%
# CREATEDDATE: 0.00%
# OWNERID: 0.00%
# HASOPPORTUNITYLINEITEM: 0.00%
# FORECASTCATEGORYNAME: 0.00%
# FORECASTCATEGORY: 0.00%
# ISWON: 0.00%
# ISCLOSED: 0.00%
# LEADSOURCE: 0.00%
# NEXTSTEP: 0.00%
# TYPE: 0.00%
# CLOSEDATE: 0.00%
# EXPECTEDREVENUE: 0.00%
# PROBABILITY: 0.00%
# AMOUNT: 0.00%
# STAGENAME: 0.00%
# DESCRIPTION: 0.00%
# NAME: 0.00%
# ISPRIVATE: 0.00%
# ACCOUNTID: 0.00%
# ORDERNUMBER__C: 0.00%

# %%
f"# columns: {len(opportunity_columns)}"
# Out:
# '# columns: 32'

# %%
opportunity_0 = opportunity[opportunity_columns].copy()
# dropped unnecessary columns for now
columns_to_drop = ['ISDELETED', 'FISCAL', 'FISCALQUARTER', 'SYSTEMMODSTAMP', 'LASTMODIFIEDBYID', 'LASTMODIFIEDDATE',
                   'CREATEDBYID', 'CREATEDDATE', 'OWNERID', 'HASOPPORTUNITYLINEITEM', 'HASOPENACTIVITY', 'LASTREFERENCEDDATE',
                   'LASTVIEWEDDATE', 'NEXTSTEP', 'CLOSEDATE', 'DESCRIPTION', 'ISPRIVATE', 'ORDERNUMBER__C']
opportunity_0.drop(columns=columns_to_drop, axis=0, inplace=True)

# %%
# Check for duplicates
print(f"Duplicates: {opportunity_0.duplicated().sum()}")
# Out:
# Duplicates: 0

# %%
opportunity_0.head()
# Out:
#                    ID TRACKINGNUMBER__C FORECASTCATEGORYNAME FORECASTCATEGORY  \
# 0  006ak000002sAjJAAU              True               Closed           Closed
# 1  006ak000002sAjKAAU              True               Closed           Closed
# 2  006ak000002sAjLAAU              True              Omitted          Omitted
# 3  006ak000002sAjMAAU              True              Omitted          Omitted
# 4  006ak000002sAjNAAU              True              Omitted          Omitted
#
#    ISWON ISCLOSED            LEADSOURCE               TYPE EXPECTEDREVENUE  \
# 0   True     True      Investment Banks  Existing Business      9803283.28
# 1   True     True      Direct Referrals  Existing Business    769708262.96
# 2  False     True      Business Brokers       New Business             0.0
# 3  False     True  Industry Conferences       New Business             0.0
# 4  False     True      Direct Referrals  Existing Business             0.0
#
#   PROBABILITY        AMOUNT    STAGENAME         NAME           ACCOUNTID
# 0       100.0    9803283.28   Closed Won   Investment  001ak00000IrTIfAAN
# 1       100.0  769708262.96   Closed Won  Acquisition  001ak00000IrtTVAAZ
# 2         0.0   15345608.43  Closed Lost  Acquisition  001ak00000IrtTWAAZ
# 3         0.0    14571650.3  Closed Lost  Acquisition  001ak00000IrtTXAAZ
# 4         0.0   53095439.02  Closed Lost   Investment  001ak00000IrtTYAAZ

# %% [markdown]
# ## Contact

# %%
contact.head()
# Out:
#                    ID ISDELETED MASTERRECORDID           ACCOUNTID  LASTNAME  \
# 0  003ak000002hSkfAAE     False           None  001ak00000IADT3AAP  Gonzalez
# 1  003ak000002hSkgAAE     False           None  001ak00000IADT3AAP    Forbes
# 2  003ak000002hSkhAAE     False           None  001ak00000IADT4AAP    Rogers
# 3  003ak000002hSkkAAE     False           None  001ak00000IADT7AAP      Barr
# 4  003ak000002hSklAAE     False           None  001ak00000IADT7AAP      Bond
#
#   FIRSTNAME SALUTATION           NAME OTHERSTREET OTHERCITY  ...  \
# 0      Rose        Ms.  Rose Gonzalez        None      None  ...
# 1      Sean        Mr.    Sean Forbes        None      None  ...
# 2      Jack        Mr.    Jack Rogers        None      None  ...
# 3       Tim        Mr.       Tim Barr        None      None  ...
# 4      John        Mr.      John Bond        None      None  ...
#
#   EMAILBOUNCEDREASON EMAILBOUNCEDDATE ISEMAILBOUNCED  \
# 0               None             None          False
# 1               None             None          False
# 2               None             None          False
# 3               None             None          False
# 4               None             None          False
#
#                                     PHOTOURL JIGSAW JIGSAWCONTACTID  \
# 0  /services/images/photo/003ak000002hSkfAAE   None            None
# 1  /services/images/photo/003ak000002hSkgAAE   None            None
# 2  /services/images/photo/003ak000002hSkhAAE   None            None
# 3  /services/images/photo/003ak000002hSkkAAE   None            None
# 4  /services/images/photo/003ak000002hSklAAE   None            None
#
#   CLEANSTATUS INDIVIDUALID   LEVEL__C LANGUAGES__C
# 0     Pending         None    Primary      English
# 1     Pending         None  Secondary      English
# 2     Pending         None       None         None
# 3     Pending         None  Secondary      English
# 4     Pending         None    Primary      English
#
# [5 rows x 59 columns]

# %%
# Handling Missing Values
print("Missing Values:")
contact_columns = print_missing_data_percentage(contact, threshold=20)
# Out:
# Missing Values:
# Columns with Missing Data Less Than or Equal to 20%:
# HOMEPHONE: 2.91%
# DESCRIPTION: 2.91%
# MAILINGCITY: 2.72%
# MAILINGSTATE: 2.72%
# MAILINGCOUNTRY: 2.72%
# DEPARTMENT: 0.19%
# MOBILEPHONE: 0.19%
# BIRTHDATE: 0.19%
# PHOTOURL: 0.00%
# ISEMAILBOUNCED: 0.00%
# SYSTEMMODSTAMP: 0.00%
# LASTMODIFIEDBYID: 0.00%
# LASTMODIFIEDDATE: 0.00%
# CREATEDBYID: 0.00%
# CREATEDDATE: 0.00%
# OWNERID: 0.00%
# ID: 0.00%
# TITLE: 0.00%
# EMAIL: 0.00%
# ISDELETED: 0.00%
# FAX: 0.00%
# PHONE: 0.00%
# MAILINGSTREET: 0.00%
# NAME: 0.00%
# SALUTATION: 0.00%
# FIRSTNAME: 0.00%
# LASTNAME: 0.00%
# ACCOUNTID: 0.00%
# CLEANSTATUS: 0.00%

# %%
f"# columns: {len(contact_columns)}"
# Out:
# '# columns: 29'

# %%
contact_0 = contact[contact_columns].copy()
# dropped unnecessary columns for now
columns_to_drop = ['HOMEPHONE', 'DESCRIPTION', 'MAILINGCITY', 'MAILINGCOUNTRY', 'MOBILEPHONE', 'BIRTHDATE', 'PHOTOURL', 'ISEMAILBOUNCED',
                   'SYSTEMMODSTAMP', 'LASTMODIFIEDBYID', 'LASTMODIFIEDDATE', 'CREATEDBYID', 'CREATEDDATE', 'OWNERID', 'EMAIL', 'ISDELETED',
                   'FAX', 'PHONE', 'MAILINGSTREET', 'SALUTATION', 'FIRSTNAME', 'LASTNAME', 'CLEANSTATUS']
contact_0.drop(columns=columns_to_drop, axis=0, inplace=True)

# From DEPARTMENT remove some default values 
values_to_drop = ['Production', 'Technology', 'Procurement', 'Facilities', 'Operations', 'Warehouse Mgmt', 'Administration', 'Executive Team']
contact_0 = contact_0[~contact_0['DEPARTMENT'].isin(values_to_drop)]

# From TITLE remove some default values
values_to_drop = ['VP, Facilities', 'VP, Production', 'VP, Technology', 'SVP, Procurement', 'VP, Finance', 'Dean of Administration', 'Director,Warehouse Mgmt',
                  'SVP, Operations', 'SVP, Technology', 'SVP, Production', 'SVP, Administration and Finance', 'Regional General Manager']
contact_0 = contact_0[~contact_0['TITLE'].isin(values_to_drop)]

# %%
contact_0.head()
# Out:
#      MAILINGSTATE DEPARTMENT                  ID            TITLE  \
# 1            None    Finance  003ak000002hSkgAAE              CFO
# 14           None    Finance  003ak000002hSkwAAE              CFO
# 15  West Virginia      Other  003ak000002nqKoAAI               VP
# 16      Tennessee    Finance  003ak000002nqKpAAI  Finance Manager
# 17      Louisiana    Finance  003ak000002nqKqAAI  Finance Manager
#
#                NAME           ACCOUNTID
# 1       Sean Forbes  001ak00000IADT3AAP
# 14        Avi Green  001ak00000IADT8AAP
# 15   Kristy Huffman  001ak00000IrTIfAAN
# 16     Bethany Frye  001ak00000IrtTVAAZ
# 17  Lawrence Powers  001ak00000IrtTWAAZ

# %% [markdown]
# ## Task

# %%
task.drop_duplicates(subset=['ID'], keep='first', inplace=True)

# %%
task.head()
# Out:
#                    ID               WHOID              WHATID  \
# 0  00Tak000001SknKEAS  003ak000002nqxxAAA  006ak000002sEVcAAM
# 1  00Tak000001SknLEAS  003ak000002nqxxAAA  006ak000002sEVcAAM
# 2  00Tak000001SknMEAS  003ak000002nqxxAAA  006ak000002sEVcAAM
# 3  00Tak000001SknNEAS  003ak000002nqxxAAA  006ak000002sEVcAAM
# 4  00Tak000001SknOEAS  003ak000002nqxyAAA  006ak000002sEVdAAM
#
#                                         SUBJECT                 ACTIVITYDATE  \
# 0   Very special discussion treat contain risk.  2023-09-06 00:00:00.0000000
# 1           Turn simply what day goal increase.  2023-09-06 00:00:00.0000000
# 2  Lose western table card just realize simple.  2023-09-06 00:00:00.0000000
# 3             Large friend human art yard hour.  2023-09-06 00:00:00.0000000
# 4                       Avoid claim lot factor.  2022-07-31 00:00:00.0000000
#
#         STATUS PRIORITY ISHIGHPRIORITY             OWNERID  \
# 0  Not Started   Normal          False  005ak000004Jxy9AAC
# 1  Not Started      Low          False  005ak000004Jxy9AAC
# 2  Not Started     High           True  005ak000004Jxy9AAC
# 3    Completed     High           True  005ak000004Jxy9AAC
# 4  Not Started      Low          False  005ak000004Jxy9AAC
#
#                                          DESCRIPTION  ...  \
# 0  Little true drive first. Alone partner budget ...  ...
# 1  Ability serve case together air build. Positiv...  ...
# 2  Debate much region main record. Vote remain bl...  ...
# 3  Everyone oil election single eight. Street occ...  ...
# 4  Exactly capital the century heavy box would. L...  ...
#
#   RECURRENCEENDDATEONLY RECURRENCETIMEZONESIDKEY RECURRENCETYPE  \
# 0                  None                     None           None
# 1                  None                     None           None
# 2                  None                     None           None
# 3                  None                     None           None
# 4                  None                     None           None
#
#   RECURRENCEINTERVAL RECURRENCEDAYOFWEEKMASK RECURRENCEDAYOFMONTH  \
# 0               None                    None                 None
# 1               None                    None                 None
# 2               None                    None                 None
# 3               None                    None                 None
# 4               None                    None                 None
#
#   RECURRENCEINSTANCE RECURRENCEMONTHOFYEAR RECURRENCEREGENERATEDTYPE  \
# 0               None                  None                      None
# 1               None                  None                      None
# 2               None                  None                      None
# 3               None                  None                      None
# 4               None                  None                      None
#
#   TASKSUBTYPE
# 0        Task
# 1        Call
# 2       Email
# 3       Email
# 4       Email
#
# [5 rows x 38 columns]

# %%
# Handling Missing Values
print("Missing Values:")
task_columns = print_missing_data_percentage(task, threshold=20)
# Out:
# Missing Values:
# Columns with Missing Data Less Than or Equal to 20%:
# ID: 0.00%
# WHOID: 0.00%
# ISRECURRENCE: 0.00%
# ISREMINDERSET: 0.00%
# CALLOBJECT: 0.00%
# CALLDISPOSITION: 0.00%
# CALLTYPE: 0.00%
# CALLDURATIONINSECONDS: 0.00%
# ISARCHIVED: 0.00%
# SYSTEMMODSTAMP: 0.00%
# LASTMODIFIEDBYID: 0.00%
# LASTMODIFIEDDATE: 0.00%
# CREATEDBYID: 0.00%
# CREATEDDATE: 0.00%
# ISCLOSED: 0.00%
# ACCOUNTID: 0.00%
# ISDELETED: 0.00%
# DESCRIPTION: 0.00%
# OWNERID: 0.00%
# ISHIGHPRIORITY: 0.00%
# PRIORITY: 0.00%
# STATUS: 0.00%
# ACTIVITYDATE: 0.00%
# SUBJECT: 0.00%
# WHATID: 0.00%
# TASKSUBTYPE: 0.00%

# %%
f"# columns: {len(task_columns)}"
# Out:
# '# columns: 26'

# %%
task_0 = task[task_columns].copy()
# dropped unnecessary columns for now
columns_to_drop = ['ISRECURRENCE', 'ISREMINDERSET', 'CALLOBJECT', 'ISARCHIVED', 'SYSTEMMODSTAMP', 'LASTMODIFIEDBYID', 'SUBJECT',
                   'LASTMODIFIEDDATE', 'CREATEDBYID', 'CREATEDDATE', 'ISDELETED', 'DESCRIPTION', 'OWNERID', 'ACTIVITYDATE']
task_0.drop(columns=columns_to_drop, axis=0, inplace=True)

# %%
task_0.columns
# Out:
# Index(['ID', 'WHOID', 'CALLDISPOSITION', 'CALLTYPE', 'CALLDURATIONINSECONDS',
#        'ISCLOSED', 'ACCOUNTID', 'ISHIGHPRIORITY', 'PRIORITY', 'STATUS',
#        'WHATID', 'TASKSUBTYPE'],
#       dtype='object')

# %%
task_0.head()
# Out:
#                    ID               WHOID                CALLDISPOSITION  \
# 0  00Tak000001SknKEAS  003ak000002nqxxAAA  Interested - Follow Up Needed
# 1  00Tak000001SknLEAS  003ak000002nqxxAAA                 Not Interested
# 2  00Tak000001SknMEAS  003ak000002nqxxAAA                 Not Interested
# 3  00Tak000001SknNEAS  003ak000002nqxxAAA                Call Successful
# 4  00Tak000001SknOEAS  003ak000002nqxyAAA            Scheduled Call Back
#
#    CALLTYPE CALLDURATIONINSECONDS ISCLOSED           ACCOUNTID ISHIGHPRIORITY  \
# 0  Internal                    68    False  001ak00000IruOBAAZ          False
# 1  Outbound                    45    False  001ak00000IruOBAAZ          False
# 2   Inbound                    39    False  001ak00000IruOBAAZ           True
# 3   Inbound                   348     True  001ak00000IruOBAAZ           True
# 4  Outbound                    38    False  001ak00000IruOCAAZ          False
#
#   PRIORITY       STATUS              WHATID TASKSUBTYPE
# 0   Normal  Not Started  006ak000002sEVcAAM        Task
# 1      Low  Not Started  006ak000002sEVcAAM        Call
# 2     High  Not Started  006ak000002sEVcAAM       Email
# 3     High    Completed  006ak000002sEVcAAM       Email
# 4      Low  Not Started  006ak000002sEVdAAM       Email

# %% [markdown]
# ## Saving the Prepro Data

# %%
account_0.to_csv('preprod_data/account.csv', index=False)
opportunity_0.to_csv('preprod_data/opportunity.csv', index=False)
contact_0.to_csv('preprod_data/contact.csv', index=False)
task_0.to_csv('preprod_data/task.csv', index=False)

# %%
ds = pd.read_csv('preprod_data/account.csv')

# %%
ds.TYPE.value_counts()
# Out:
# TYPE
# Established     271
# Startup         161
# Growth Stage     68
# Name: count, dtype: int64

# %%
os = pd.read_csv('preprod_data/opportunity.csv')

# %%
os.STAGENAME.value_counts()
# Out:
# STAGENAME
# Closed Lost             287
# Closed Won               66
# Value Proposition        29
# Prospecting              25
# Needs Analysis           23
# Qualification            18
# Negotiation/Review       15
# Proposal/Price Quote     13
# Perception Analysis      13
# Id. Decision Makers      11
# Name: count, dtype: int64

# %%
os
# Out:
#                      ID  TRACKINGNUMBER__C FORECASTCATEGORYNAME  \
# 0    006ak000002sAjJAAU               True               Closed
# 1    006ak000002sAjKAAU               True               Closed
# 2    006ak000002sAjLAAU               True              Omitted
# 3    006ak000002sAjMAAU               True              Omitted
# 4    006ak000002sAjNAAU               True              Omitted
# ..                  ...                ...                  ...
# 495  006ak000002sEZQAA2               True             Pipeline
# 496  006ak000002sEZRAA2               True              Omitted
# 497  006ak000002sEZSAA2               True             Pipeline
# 498  006ak000002sEZTAA2               True              Omitted
# 499  006ak000002sEZUAA2               True              Omitted
#
#     FORECASTCATEGORY  ISWON  ISCLOSED            LEADSOURCE  \
# 0             Closed   True      True      Investment Banks
# 1             Closed   True      True      Direct Referrals
# 2            Omitted  False      True      Business Brokers
# 3            Omitted  False      True  Industry Conferences
# 4            Omitted  False      True      Direct Referrals
# ..               ...    ...       ...                   ...
# 495         Pipeline  False     False      Investment Banks
# 496          Omitted  False      True     Networking Events
# 497         Pipeline  False     False     Networking Events
# 498          Omitted  False      True      Direct Referrals
# 499          Omitted  False      True  Industry Conferences
#
#                   TYPE  EXPECTEDREVENUE  PROBABILITY        AMOUNT  \
# 0    Existing Business     9.803283e+06        100.0  9.803283e+06
# 1    Existing Business     7.697083e+08        100.0  7.697083e+08
# 2         New Business     0.000000e+00          0.0  1.534561e+07
# 3         New Business     0.000000e+00          0.0  1.457165e+07
# 4    Existing Business     0.000000e+00          0.0  5.309544e+07
# ..                 ...              ...          ...           ...
# 495  Existing Business     8.059185e+07         70.0  1.151312e+08
# 496  Existing Business     0.000000e+00          0.0  2.245262e+08
# 497  Existing Business     1.099439e+09         75.0  1.465919e+09
# 498  Existing Business     0.000000e+00          0.0  1.249053e+09
# 499  Existing Business     0.000000e+00          0.0  1.372094e+08
#
#                 STAGENAME         NAME           ACCOUNTID
# 0              Closed Won   Investment  001ak00000IrTIfAAN
# 1              Closed Won  Acquisition  001ak00000IrtTVAAZ
# 2             Closed Lost  Acquisition  001ak00000IrtTWAAZ
# 3             Closed Lost  Acquisition  001ak00000IrtTXAAZ
# 4             Closed Lost   Investment  001ak00000IrtTYAAZ
# ..                    ...          ...                 ...
# 495   Perception Analysis   Investment  001ak00000IruJwAAJ
# 496           Closed Lost  Acquisition  001ak00000IruJxAAJ
# 497  Proposal/Price Quote  Acquisition  001ak00000IruJyAAJ
# 498           Closed Lost  Acquisition  001ak00000IruJzAAJ
# 499           Closed Lost   Investment  001ak00000IruK0AAJ
#
# [500 rows x 14 columns]

# %%
cc = pd.read_csv('preprod_data/contact.csv')

# %%
cc.ACCOUNTID.value_counts()
# Out:
# ACCOUNTID
# 001ak00000IADT3AAP    1
# 001ak00000IruOCAAZ    1
# 001ak00000IqvqUAAR    1
# 001ak00000IqvqTAAR    1
# 001ak00000IqvqSAAR    1
#                      ..
# 001ak00000IruLBAAZ    1
# 001ak00000IruLAAAZ    1
# 001ak00000IruL9AAJ    1
# 001ak00000IrTIUAA3    1
# 001ak00000IruK0AAJ    1
# Name: count, Length: 502, dtype: int64

# %%
opportunity = pd.read_csv('preprod_data/opportunity.csv')
task = pd.read_csv('preprod_data/task.csv')

# %%
opportunity.head()
# Out:
#                    ID  TRACKINGNUMBER__C FORECASTCATEGORYNAME  \
# 0  006ak000002sAjJAAU               True               Closed
# 1  006ak000002sAjKAAU               True               Closed
# 2  006ak000002sAjLAAU               True              Omitted
# 3  006ak000002sAjMAAU               True              Omitted
# 4  006ak000002sAjNAAU               True              Omitted
#
#   FORECASTCATEGORY  ISWON  ISCLOSED            LEADSOURCE               TYPE  \
# 0           Closed   True      True      Investment Banks  Existing Business
# 1           Closed   True      True      Direct Referrals  Existing Business
# 2          Omitted  False      True      Business Brokers       New Business
# 3          Omitted  False      True  Industry Conferences       New Business
# 4          Omitted  False      True      Direct Referrals  Existing Business
#
#    EXPECTEDREVENUE  PROBABILITY        AMOUNT    STAGENAME         NAME  \
# 0     9.803283e+06        100.0  9.803283e+06   Closed Won   Investment
# 1     7.697083e+08        100.0  7.697083e+08   Closed Won  Acquisition
# 2     0.000000e+00          0.0  1.534561e+07  Closed Lost  Acquisition
# 3     0.000000e+00          0.0  1.457165e+07  Closed Lost  Acquisition
# 4     0.000000e+00          0.0  5.309544e+07  Closed Lost   Investment
#
#             ACCOUNTID
# 0  001ak00000IrTIfAAN
# 1  001ak00000IrtTVAAZ
# 2  001ak00000IrtTWAAZ
# 3  001ak00000IrtTXAAZ
# 4  001ak00000IrtTYAAZ

# %%
task.head()
# Out:
#                    ID               WHOID                CALLDISPOSITION  \
# 0  00Tak000001SknKEAS  003ak000002nqxxAAA  Interested - Follow Up Needed
# 1  00Tak000001SknLEAS  003ak000002nqxxAAA                 Not Interested
# 2  00Tak000001SknMEAS  003ak000002nqxxAAA                 Not Interested
# 3  00Tak000001SknNEAS  003ak000002nqxxAAA                Call Successful
# 4  00Tak000001SknOEAS  003ak000002nqxyAAA            Scheduled Call Back
#
#    CALLTYPE  CALLDURATIONINSECONDS  ISCLOSED           ACCOUNTID  \
# 0  Internal                     68     False  001ak00000IruOBAAZ
# 1  Outbound                     45     False  001ak00000IruOBAAZ
# 2   Inbound                     39     False  001ak00000IruOBAAZ
# 3   Inbound                    348      True  001ak00000IruOBAAZ
# 4  Outbound                     38     False  001ak00000IruOCAAZ
#
#    ISHIGHPRIORITY PRIORITY       STATUS              WHATID TASKSUBTYPE
# 0           False   Normal  Not Started  006ak000002sEVcAAM        Task
# 1           False      Low  Not Started  006ak000002sEVcAAM        Call
# 2            True     High  Not Started  006ak000002sEVcAAM       Email
# 3            True     High    Completed  006ak000002sEVcAAM       Email
# 4           False      Low  Not Started  006ak000002sEVdAAM       Email

# %%
ds = opportunity.merge(task, left_on="ID", right_on="WHATID", how="left")

# %%
ds = ds[ds.STAGENAME.isin(['Closed Won', 'Closed Lost'])].copy()

# %%
pd.pivot_table(ds, index="index_col", values="value_col", aggfunc=aggfunc)
# Out:
#                     ID_x  TRACKINGNUMBER__C FORECASTCATEGORYNAME  \
# 0     006ak000002sAjJAAU               True               Closed
# 1     006ak000002sAjJAAU               True               Closed
# 2     006ak000002sAjJAAU               True               Closed
# 3     006ak000002sAjJAAU               True               Closed
# 4     006ak000002sAjJAAU               True               Closed
# ...                  ...                ...                  ...
# 1519  006ak000002sEZTAA2               True              Omitted
# 1520  006ak000002sEZUAA2               True              Omitted
# 1521  006ak000002sEZUAA2               True              Omitted
# 1522  006ak000002sEZUAA2               True              Omitted
# 1523  006ak000002sEZUAA2               True              Omitted
#
#      FORECASTCATEGORY  ISWON  ISCLOSED_x            LEADSOURCE  \
# 0              Closed   True        True      Investment Banks
# 1              Closed   True        True      Investment Banks
# 2              Closed   True        True      Investment Banks
# 3              Closed   True        True      Investment Banks
# 4              Closed   True        True      Investment Banks
# ...               ...    ...         ...                   ...
# 1519          Omitted  False        True      Direct Referrals
# 1520          Omitted  False        True  Industry Conferences
# 1521          Omitted  False        True  Industry Conferences
# 1522          Omitted  False        True  Industry Conferences
# 1523          Omitted  False        True  Industry Conferences
#
#                    TYPE  EXPECTEDREVENUE  PROBABILITY  ...  \
# 0     Existing Business       9803283.28        100.0  ...
# 1     Existing Business       9803283.28        100.0  ...
# 2     Existing Business       9803283.28        100.0  ...
# 3     Existing Business       9803283.28        100.0  ...
# 4     Existing Business       9803283.28        100.0  ...
# ...                 ...              ...          ...  ...
# 1519  Existing Business             0.00          0.0  ...
# 1520  Existing Business             0.00          0.0  ...
# 1521  Existing Business             0.00          0.0  ...
# 1522  Existing Business             0.00          0.0  ...
# 1523  Existing Business             0.00          0.0  ...
#
#                     CALLDISPOSITION  CALLTYPE CALLDURATIONINSECONDS  \
# 0                   Call Successful  Internal                   314
# 1                         No Answer   Inbound                    57
# 2                   Call Successful  Outbound                   598
# 3     Interested - Follow Up Needed  Internal                    91
# 4                   Call Successful  Outbound                   355
# ...                             ...       ...                   ...
# 1519  Interested - Follow Up Needed   Inbound                    74
# 1520                 Not Interested  Internal                    34
# 1521                Call Successful   Inbound                   503
# 1522  Interested - Follow Up Needed  Internal                    99
# 1523                 Not Interested  Internal                    34
#
#      ISCLOSED_y         ACCOUNTID_y ISHIGHPRIORITY PRIORITY       STATUS  \
# 0          True  001ak00000IrTIfAAN          False   Normal    Completed
# 1         False  001ak00000IrTIfAAN           True     High  Not Started
# 2          True  001ak00000IrTIfAAN          False   Normal    Completed
# 3         False  001ak00000IrTIfAAN          False      Low  Not Started
# 4          True  001ak00000IrTIfAAN           True     High    Completed
# ...         ...                 ...            ...      ...          ...
# 1519      False  001ak00000IruJzAAJ           True     High  Not Started
# 1520      False  001ak00000IruK0AAJ          False      Low  Not Started
# 1521       True  001ak00000IruK0AAJ           True     High    Completed
# 1522      False  001ak00000IruK0AAJ           True     High  Not Started
# 1523      False  001ak00000IruK0AAJ          False   Normal  Not Started
#
#                   WHATID  TASKSUBTYPE
# 0     006ak000002sAjJAAU         Task
# 1     006ak000002sAjJAAU         Call
# 2     006ak000002sAjJAAU         Task
# 3     006ak000002sAjJAAU         Task
# 4     006ak000002sAjJAAU         Call
# ...                  ...          ...
# 1519  006ak000002sEZTAA2         Task
# 1520  006ak000002sEZUAA2        Email
# 1521  006ak000002sEZUAA2        Email
# 1522  006ak000002sEZUAA2        Email
# 1523  006ak000002sEZUAA2         Task
#
# [1524 rows x 26 columns]

# %%
opportunity.columns
# Out:
# Index(['ID', 'TRACKINGNUMBER__C', 'FORECASTCATEGORYNAME', 'FORECASTCATEGORY',
#        'ISWON', 'ISCLOSED', 'LEADSOURCE', 'TYPE', 'EXPECTEDREVENUE',
#        'PROBABILITY', 'AMOUNT', 'STAGENAME', 'NAME', 'ACCOUNTID'],
#       dtype='object')

# %%
opportunity.STAGENAME.value_counts()
# Out:
# STAGENAME
# Closed Lost             287
# Closed Won               66
# Value Proposition        29
# Prospecting              25
# Needs Analysis           23
# Qualification            18
# Negotiation/Review       15
# Proposal/Price Quote     13
# Perception Analysis      13
# Id. Decision Makers      11
# Name: count, dtype: int64

# %%
ds.STAGENAME.value_counts()
# Out:
# STAGENAME
# Closed Lost    691
# Closed Won     309
# Name: count, dtype: int64

# %%
callduration = task.groupby(['WHATID', 'TASKSUBTYPE']).sum().reset_index()[['WHATID', 'TASKSUBTYPE', 'CALLDURATIONINSECONDS']]
callduration['CALLDURATIONINSECONDS'] = callduration['CALLDURATIONINSECONDS'].astype(float)

# %%
call_duration_df = callduration[callduration['TASKSUBTYPE']=='Call'][['WHATID', 'CALLDURATIONINSECONDS']].groupby(['WHATID']).agg('mean').reset_index()

# %%
task.groupby(['WHATID', 'TASKSUBTYPE']).count().reset_index()[['WHATID', 'TASKSUBTYPE', 'STATUS']]
# Out:
#                  WHATID TASKSUBTYPE  STATUS
# 0    006ak000002sAjJAAU        Call       3
# 1    006ak000002sAjJAAU        Task       3
# 2    006ak000002sAjKAAU        Call       4
# 3    006ak000002sAjKAAU       Email       1
# 4    006ak000002sAjLAAU        Call       1
# ..                  ...         ...     ...
# 907  006ak000002sEZSAA2        Call       2
# 908  006ak000002sEZSAA2       Email       2
# 909  006ak000002sEZTAA2        Task       1
# 910  006ak000002sEZUAA2       Email       3
# 911  006ak000002sEZUAA2        Task       1
#
# [912 rows x 3 columns]

# %%
task.TASKSUBTYPE

# %%
task.head()
# Out:
#                    ID               WHOID                CALLDISPOSITION  \
# 0  00Tak000001SknKEAS  003ak000002nqxxAAA  Interested - Follow Up Needed
# 1  00Tak000001SknLEAS  003ak000002nqxxAAA                 Not Interested
# 2  00Tak000001SknMEAS  003ak000002nqxxAAA                 Not Interested
# 3  00Tak000001SknNEAS  003ak000002nqxxAAA                Call Successful
# 4  00Tak000001SknOEAS  003ak000002nqxyAAA            Scheduled Call Back
#
#    CALLTYPE  CALLDURATIONINSECONDS  ISCLOSED           ACCOUNTID  \
# 0  Internal                     68     False  001ak00000IruOBAAZ
# 1  Outbound                     45     False  001ak00000IruOBAAZ
# 2   Inbound                     39     False  001ak00000IruOBAAZ
# 3   Inbound                    348      True  001ak00000IruOBAAZ
# 4  Outbound                     38     False  001ak00000IruOCAAZ
#
#    ISHIGHPRIORITY PRIORITY       STATUS              WHATID TASKSUBTYPE
# 0           False   Normal  Not Started  006ak000002sEVcAAM        Task
# 1           False      Low  Not Started  006ak000002sEVcAAM        Call
# 2            True     High  Not Started  006ak000002sEVcAAM       Email
# 3            True     High    Completed  006ak000002sEVcAAM       Email
# 4           False      Low  Not Started  006ak000002sEVdAAM       Email

# %%
call_duration_df
# Out:
#                  WHATID  CALLDURATIONINSECONDS
# 0    006ak000002sAjJAAU                  515.0
# 1    006ak000002sAjKAAU                  621.0
# 2    006ak000002sAjLAAU                   30.0
# 3    006ak000002sAjMAAU                  564.0
# 4    006ak000002sAjQAAU                   90.0
# ..                  ...                    ...
# 247  006ak000002sEZGAA2                  256.0
# 248  006ak000002sEZHAA2                  350.0
# 249  006ak000002sEZIAA2                  143.0
# 250  006ak000002sEZQAA2                   84.0
# 251  006ak000002sEZSAA2                   83.0
#
# [252 rows x 2 columns]

# %%
something = opportunity.merge(call_duration_df, left_on='ID', right_on='WHATID', how='left')[['STAGENAME', 'CALLDURATIONINSECONDS']]

# %%
something = something[something.STAGENAME.isin(['Closed Won', 'Closed Lost'])].copy()

# %%
something['CALLDURATIONINSECONDS'] = something['CALLDURATIONINSECONDS'].fillna(0)

# %%
something
# Out:
#        STAGENAME  CALLDURATIONINSECONDS
# 0     Closed Won                  515.0
# 1     Closed Won                  621.0
# 2    Closed Lost                   30.0
# 3    Closed Lost                  564.0
# 4    Closed Lost                    0.0
# ..           ...                    ...
# 492  Closed Lost                    0.0
# 493  Closed Lost                    0.0
# 496  Closed Lost                    0.0
# 498  Closed Lost                    0.0
# 499  Closed Lost                    0.0
#
# [353 rows x 2 columns]

# %%
pd.pivot_table(something, index="STAGENAME", values="CALLDURATIONINSECONDS")
# Out:
#              CALLDURATIONINSECONDS
# STAGENAME
# Closed Lost              52.066202
# Closed Won              533.090909
